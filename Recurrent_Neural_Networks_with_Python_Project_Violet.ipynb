# %% [markdown]
# # <font color='#2F4F4F'>AfterWork Data Science: Recurrent Neural Networks with Python - Project</font>

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1. Business Understanding </font>

# %% [markdown]
# ### a) Specifying the Research Question
#
# Build a recurrent neural networks model that will be used to predict Tesla stock prices in 2017 using data from 2012-2016

# %% [markdown]
# ### b) Defining the Metric for Success
#
# Build a neural networks regression model with an RSME  less than 10% of the target mean.

# %% [markdown]
# ### c) Understanding the Context
#
# Stockpy is an innovative fintech enabling financial prosperity for the entire population. It is a venture funded startup based in Palo Alto bringing world-class financial experiences to a continually growing customer base. As Stockpy enters an expansion phase for innovative fintech product offerings, it aims to enhance the enormous value in data processing and analysis for continuous growth and success.
#
# As a Finance Data Scientist for Stockpy, you provide leadership to turn cutting-edge technology into actionable insights; unlocking the power of data that provides value to business decisions and customer service enhancements.

# %% [markdown]
# ### d) Recording the Experimental Design
#
# * Business Understanding
# * Data Exploration
# * Data Preparation
# * Data Modeling and Evaluation
# * Summary of Findings and Recommendation
# * Challenging the Solution

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2. Data Importation</font>

# %%
# Importing standard libraries
# ---
# 
import pandas as pd              
import numpy as np               
import matplotlib.pyplot as plt

# %%
# Importing our dataset
# ---
#
df_train=pd.read_csv("https://bit.ly/38dSbSb")

df_train.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close   Volume
# 0  2012-01-03  5.788  5.900  5.530  5.616      5.616  4640500
# 1  2012-01-04  5.642  5.734  5.500  5.542      5.542  3150500
# 2  2012-01-05  5.552  5.586  5.370  5.424      5.424  5027500
# 3  2012-01-06  5.440  5.558  5.282  5.382      5.382  4931500
# 4  2012-01-09  5.400  5.498  5.224  5.450      5.450  4485000

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3. Data Exploration</font>

# %%
# Sample dataset
# ---
df_train.sample(5)
# Out:
#             Date       Open       High  ...      Close  Adj Close    Volume
# 735   2014-12-04  45.720001  46.180000  ...  45.655998  45.655998  19278000
# 566   2014-04-04  45.202000  45.653999  ...  42.445999  42.445999  56728000
# 1208  2016-10-20  40.424000  40.599998  ...  39.820000  39.820000  25364500
# 1204  2016-10-14  40.132000  40.285999  ...  39.301998  39.301998  21349500
# 654   2014-08-11  51.096001  52.748001  ...  51.863998  51.863998  40506500
#
# [5 rows x 7 columns]

# %%
# Statistical summary
# ---
#
df_train.describe()
# Out:
#               Open         High  ...    Adj Close        Volume
# count  1258.000000  1258.000000  ...  1258.000000  1.258000e+03
# mean     31.997898    32.558671  ...    31.989245  2.551310e+07
# std      16.911515    17.148543  ...    16.903500  2.259037e+07
# min       5.324000     5.370000  ...     4.558000  1.824500e+06
# 25%       8.403000     8.556000  ...     8.379500  1.059400e+07
# 50%      39.411000    40.123998  ...    39.427000  2.007650e+07
# 75%      45.214499    45.934999  ...    45.076502  3.245150e+07
# max      57.534000    58.284000  ...    57.208000  1.858195e+08
#
# [8 rows x 6 columns]

# %% [markdown]
# ## <font color='#2F4F4F'>Step 4. Data Preparation</font>

# %%
# Getting our train dataset
# ---
#
train_set = df_train.iloc[:, 1:2].values
print(train_set)
# Out:
# [[ 5.788   ]
#  [ 5.642   ]
#  [ 5.552   ]
#  ...
#  [44.306   ]
#  [43.712002]
#  [43.259998]]

# %%
# Performing Feature scaling
# ---
#
from sklearn.preprocessing import MinMaxScaler
sc =  MinMaxScaler(feature_range = (0, 1))
train_set_scaled = sc.fit_transform(train_set)
print(train_set_scaled)
# Out:
# [[0.00888719]
#  [0.00609079]
#  [0.00436698]
#  ...
#  [0.74663857]
#  [0.73526148]
#  [0.72660406]]

# %%
# Creating a dataset with 60 timesteps and 1 output
# ---
#
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(train_set_scaled[i-60:i, 0])
    y_train.append(train_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping 
# ---
#
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ##  <font color='#2F4F4F'>Step 5. Data Modeling</font>

# %%
# import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
#Initialize RNN

regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = False))
regressor.add(Dropout(0.2))

# Adding the output layer

regressor.add(Dense(units = 1))

# %%
# Compile the RNN 

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the training set
# ---
#
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 13s 60ms/step - loss: 0.0404
# Epoch 2/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0100
# Epoch 3/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0080
# Epoch 4/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0078
# Epoch 5/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0072
# Epoch 6/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0067
# Epoch 7/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0061
# Epoch 8/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0060
# Epoch 9/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0070
# Epoch 10/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0062
# Epoch 11/100
# 38/38 [==============================] - 2s 64ms/step - loss: 0.0060
# Epoch 12/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0055
# Epoch 13/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0053
# Epoch 14/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0062
# Epoch 15/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0050
# Epoch 16/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0050
# Epoch 17/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0045
# Epoch 18/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0048
# Epoch 19/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0055
# Epoch 20/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0046
# Epoch 21/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0045
# Epoch 22/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0048
# Epoch 23/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0041
# Epoch 24/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0042
# Epoch 25/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0042
# Epoch 26/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0042
# Epoch 27/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0044
# Epoch 28/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0040
# Epoch 29/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0043
# Epoch 30/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0040
# Epoch 31/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0040
# Epoch 32/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0044
# Epoch 33/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0037
# Epoch 34/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0039
# Epoch 35/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0037
# Epoch 36/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0034
# Epoch 37/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0034
# Epoch 38/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0033
# Epoch 39/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0034
# Epoch 40/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0032
# Epoch 41/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0034
# Epoch 42/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0035
# Epoch 43/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0032
# Epoch 44/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0033
# Epoch 45/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0033
# Epoch 46/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0033
# Epoch 47/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0029
# Epoch 48/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0029
# Epoch 49/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0030
# Epoch 50/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0032
# Epoch 51/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0028
# Epoch 52/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0031
# Epoch 53/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0030
# Epoch 54/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0026
# Epoch 55/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0029
# Epoch 56/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0028
# Epoch 57/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0026
# Epoch 58/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0026
# Epoch 59/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0029
# Epoch 60/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0025
# Epoch 61/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0027
# Epoch 62/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0027
# Epoch 63/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0029
# Epoch 64/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0030
# Epoch 65/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0026
# Epoch 66/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0026
# Epoch 67/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0028
# Epoch 68/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0025
# Epoch 69/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0024
# Epoch 70/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0026
# Epoch 71/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0032
# Epoch 72/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0026
# Epoch 73/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0025
# Epoch 74/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0023
# Epoch 75/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0023
# Epoch 76/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0024
# Epoch 77/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0022
# Epoch 78/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0020
# Epoch 79/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0023
# Epoch 80/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0023
# Epoch 81/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0023
# Epoch 82/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0022
# Epoch 83/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0023
# Epoch 84/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0022
# Epoch 85/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0021
# Epoch 86/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0022
# Epoch 87/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0019
# Epoch 88/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0022
# Epoch 89/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0019
# Epoch 90/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0019
# Epoch 91/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0018
# Epoch 92/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0020
# Epoch 93/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0022
# Epoch 94/100
# 38/38 [==============================] - 2s 60ms/step - loss: 0.0021
# Epoch 95/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0020
# Epoch 96/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0021
# Epoch 97/100
# 38/38 [==============================] - 2s 62ms/step - loss: 0.0021
# Epoch 98/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0019
# Epoch 99/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0021
# Epoch 100/100
# 38/38 [==============================] - 2s 61ms/step - loss: 0.0017

# %%
# Making predictions: Getting the predicted stock price for 2017
# ---
#get test dataset

df_test=pd.read_csv("tslatest.csv")
df_test.head(20)
# Out:
#           Date       Open       High        Low      Close  Adj Close    Volume
# 0   2017-01-03  42.972000  44.066002  42.192001  43.397999  43.397999  29616500
# 1   2017-01-04  42.950001  45.599998  42.862000  45.397999  45.397999  56067500
# 2   2017-01-05  45.284000  45.495998  44.389999  45.349998  45.349998  29558500
# 3   2017-01-06  45.386002  46.062000  45.090000  45.801998  45.801998  27639500
# 4   2017-01-09  45.793999  46.383999  45.599998  46.256001  46.256001  19897500
# 5   2017-01-10  46.400002  46.400002  45.377998  45.973999  45.973999  18300000
# 6   2017-01-11  45.813999  45.995998  45.335999  45.945999  45.945999  18254000
# 7   2017-01-12  45.812000  46.139999  45.116001  45.917999  45.917999  18951000
# 8   2017-01-13  46.000000  47.570000  45.917999  47.549999  47.549999  30465000
# 9   2017-01-17  47.340000  47.992001  46.874001  47.116001  47.116001  23087500
# 10  2017-01-18  47.330002  47.942001  47.116001  47.672001  47.672001  18845000
# 11  2017-01-19  49.450001  49.736000  48.150002  48.751999  48.751999  38661500
# 12  2017-01-20  49.091999  49.200001  48.602001  48.945999  48.945999  21021500
# 13  2017-01-23  49.169998  50.178001  49.099998  49.784000  49.784000  31314500
# 14  2017-01-24  50.000000  50.959999  49.930000  50.922001  50.922001  24827500
# 15  2017-01-25  51.462002  51.692001  50.360001  50.894001  50.894001  25713000
# 16  2017-01-26  50.858002  51.147999  50.150002  50.501999  50.501999  15760500
# 17  2017-01-27  50.276001  50.599998  49.703999  50.590000  50.590000  15831500
# 18  2017-01-30  50.506001  51.057999  49.419998  50.125999  50.125999  19005500
# 19  2017-01-31  49.848000  51.178001  49.540001  50.386002  50.386002  20580500

# %%
real_price = df_test.iloc[:, 1:2].values




# Getting the Predicted Stock Price of 2017

#
dataset = pd.concat((df_train['Open'],
                           df_test['Open']), axis=0)

#
inputs = dataset[len(dataset)-len(df_test)-60:].values

# Reshaping the inputs to have only 1 column
# ---
#
inputs = inputs.reshape(-1, 1)


# Using the scale set by the training set to scale the test inputs
# ---
#
inputs = sc.transform(inputs)

# Then creating the test data structure just as we did for the train dataset
# ---

X_test = []
y_test = []

for i in range(60, len(inputs)):
    X_test.append(inputs[i-60:i, 0])
    y_test.append(inputs[i, 0])

X_test, y_test  = np.array(X_test), np.array(y_test)  
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))


# Making our Predictions
# ---
#
predicted_price = regressor.predict(X_test)


predicted_price = sc.inverse_transform(predicted_price)
print(predicted_price)
# Out:
# [[43.520947]
#  [43.20457 ]
#  [42.869595]
#  [43.407917]
#  [44.349083]
#  [45.168552]
#  [45.749165]
#  [45.79865 ]
#  [45.588753]
#  [45.459103]
#  [45.918217]
#  [46.526764]
#  [47.661816]
#  [48.449596]
#  [48.687984]
#  [48.9161  ]
#  [49.676846]
#  [50.139782]
#  [49.98994 ]
#  [49.762188]
#  [49.41297 ]
#  [49.47743 ]
#  [49.366695]
#  [49.458252]
#  [49.53943 ]
#  [50.114197]
#  [50.584045]
#  [51.462402]
#  [52.40863 ]
#  [52.957554]
#  [53.798374]
#  [54.449833]
#  [54.46307 ]
#  [53.219643]
#  [53.039536]
#  [53.915688]
#  [53.300262]
#  [51.44291 ]
#  [49.700733]
#  [48.52518 ]
#  [48.841877]
#  [49.380737]
#  [49.65668 ]
#  [49.390907]
#  [49.285965]
#  [48.96119 ]
#  [48.711468]
#  [48.523094]
#  [48.34492 ]
#  [48.34283 ]
#  [49.259884]
#  [50.664173]
#  [51.6718  ]
#  [51.669933]
#  [51.474575]
#  [50.481182]
#  [49.96671 ]
#  [50.007217]
#  [50.67588 ]
#  [52.683548]
#  [54.35431 ]
#  [54.79038 ]
#  [54.58192 ]
#  [55.074497]
#  [56.63287 ]
#  [58.2635  ]
#  [58.330475]
#  [57.905357]
#  [58.836834]
#  [60.20129 ]
#  [60.04584 ]
#  [58.495956]
#  [58.119007]
#  [58.094364]
#  [58.52429 ]
#  [59.24246 ]
#  [59.063396]
#  [59.414017]
#  [59.557808]
#  [60.00372 ]
#  [60.172806]
#  [59.935   ]
#  [60.28182 ]
#  [61.637123]
#  [61.663677]
#  [60.119965]
#  [58.179535]
#  [58.66471 ]
#  [59.62286 ]
#  [61.457165]
#  [62.452587]
#  [62.6206  ]
#  [61.556442]
#  [60.824833]
#  [60.38372 ]
#  [59.610126]
#  [60.19391 ]
#  [60.548992]
#  [60.29933 ]
#  [59.5509  ]
#  [59.591087]
#  [60.554474]
#  [62.186504]
#  [64.25563 ]
#  [65.6363  ]
#  [65.13684 ]
#  [64.38716 ]
#  [64.95903 ]
#  [67.111984]
#  [69.09448 ]
#  [70.81332 ]
#  [68.45715 ]
#  [68.612114]
#  [71.040504]
#  [70.86598 ]
#  [71.09406 ]
#  [70.57608 ]
#  [70.64126 ]
#  [70.43312 ]
#  [70.92897 ]
#  [71.75919 ]
#  [72.502625]
#  [70.89756 ]
#  [68.85964 ]
#  [68.99868 ]
#  [68.661224]
#  [69.56227 ]
#  [66.7371  ]
#  [61.874374]
#  [59.519737]
#  [59.261513]
#  [60.369007]
#  [62.76444 ]
#  [63.62925 ]
#  [62.362072]
#  [61.61747 ]
#  [60.631176]
#  [61.590786]
#  [62.45285 ]
#  [63.009007]
#  [63.145622]
#  [64.880806]
#  [65.19525 ]
#  [65.6366  ]
#  [64.59628 ]
#  [63.89181 ]
#  [62.355682]
#  [61.342323]
#  [64.32333 ]
#  [66.70838 ]
#  [68.21935 ]
#  [68.03119 ]
#  [67.95546 ]
#  [68.034996]
#  [67.5815  ]
#  [68.53517 ]
#  [69.15227 ]
#  [68.8957  ]
#  [68.35647 ]
#  [67.0513  ]
#  [65.75854 ]
#  [64.923164]
#  [64.623985]
#  [66.42774 ]
#  [67.58072 ]
#  [66.56459 ]
#  [64.728386]
#  [65.317024]
#  [66.68355 ]
#  [67.61954 ]
#  [67.292435]
#  [66.291016]
#  [65.46353 ]
#  [65.77684 ]
#  [66.546234]
#  [68.63994 ]
#  [69.16398 ]
#  [68.84215 ]
#  [69.92953 ]
#  [71.23336 ]
#  [71.44828 ]
#  [70.18629 ]
#  [70.018074]
#  [69.07288 ]
#  [67.13255 ]
#  [66.33186 ]
#  [66.31966 ]
#  [65.29661 ]
#  [65.027016]
#  [65.12999 ]
#  [64.387184]
#  [65.854095]
#  [67.35554 ]
#  [67.210526]
#  [66.237495]
#  [65.441734]
#  [66.30353 ]
#  [66.917564]
#  [67.57929 ]
#  [67.22657 ]
#  [66.528946]
#  [66.97256 ]
#  [67.33817 ]
#  [67.06486 ]
#  [66.47371 ]
#  [64.85048 ]
#  [64.00676 ]
#  [62.935265]
#  [61.71247 ]
#  [61.21892 ]
#  [61.368656]
#  [62.97682 ]
#  [60.141235]
#  [57.956684]
#  [57.925255]
#  [58.154938]
#  [58.777504]
#  [58.760883]
#  [58.485313]
#  [58.03484 ]
#  [59.384975]
#  [59.563297]
#  [60.084866]
#  [61.7043  ]
#  [61.21798 ]
#  [60.149956]
#  [60.287746]
#  [60.470528]
#  [60.547672]
#  [60.88787 ]
#  [61.177353]
#  [60.26907 ]
#  [59.270267]
#  [58.991043]
#  [58.679768]
#  [58.355152]
#  [59.450836]
#  [60.60538 ]
#  [60.929703]
#  [62.529415]
#  [64.669655]
#  [65.34902 ]
#  [65.20735 ]
#  [65.3322  ]
#  [64.92072 ]
#  [63.87298 ]
#  [63.144657]
#  [63.071476]
#  [62.61055 ]
#  [61.4643  ]
#  [60.397408]]

# %%
# Visualizing the results
# ---
#
#
plt.plot(real_price, color='red', label='Real Google Stock Price')
plt.plot(predicted_price, color='blue',
         label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction by TDP')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# Model Evaluation

import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(real_price, predicted_price))
print(rmse)
# Out:
# 3.2001526975291408

# %% [markdown]
# ## <font color='#2F4F4F'>Step 6. Summary of Findings and Recommendation</font>

# %% [markdown]
# - The RMSE value obtained is 3.2 which is almost 10% of the target mean (31.99). This means the model is of high performance
#
# - The visualization on real and predicted values shows a similar pattern, indicating a high model accuracy

# %% [markdown]
# ## <font color='#2F4F4F'>Step 7. Challenging our Solution</font>

# %% [markdown]
# #### a) Did we have the right question?
# Yes
#
#
# #### b) Did we have the right data?
# Yes, the data we had was sufficient in answering the research question
#
#
# #### c) What can be done to improve the solution?
#
# The model performance can be improved through:
#
# - Training with more data
# - Adding more LSTM layers
# - Increasing the timesteps
# - Adding some other indicators
# - Adding more neurons in the LSTM layers
